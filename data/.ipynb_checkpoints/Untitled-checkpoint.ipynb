# %%
import pandas as pd

# %%
df_messages=pd.read_csv("disaster_messages.csv")
df_cat=pd.read_csv("disaster_categories.csv")

# %%
df_messages
# Out:
#        Unnamed: 0     id                                            message  \
# 0               0      2    weather update cold front cuba could pass haiti
# 1               1      7                                          hurricane
# 2               2      8                               looking someone name
# 3               3      9  un reports leogane destroyed hospital st croix...
# 4               4     12    says west side haiti rest country today tonight
# ...           ...    ...                                                ...
# 26243       26243  30261  training demonstrated enhance micronutrient pr...
# 26244       26244  30262  suitable candidate selected ocha jakarta curre...
# 26245       26245  30263  proshika operating cox s bazar municipality un...
# 26246       26246  30264  women protesting conduct elections teargassed ...
# 26247       26247  30265  radical shift thinking came result meeting rec...
#
# ...

# %%
df_cat
# Out:
#           id                                         categories
# 0          2  related-1;request-0;offer-0;aid_related-0;medi...
# 1          7  related-1;request-0;offer-0;aid_related-1;medi...
# 2          8  related-1;request-0;offer-0;aid_related-0;medi...
# 3          9  related-1;request-1;offer-0;aid_related-1;medi...
# 4         12  related-1;request-0;offer-0;aid_related-0;medi...
# ...      ...                                                ...
# 26243  30261  related-0;request-0;offer-0;aid_related-0;medi...
# 26244  30262  related-0;request-0;offer-0;aid_related-0;medi...
# 26245  30263  related-1;request-0;offer-0;aid_related-0;medi...
# 26246  30264  related-1;request-0;offer-0;aid_related-1;medi...
# 26247  30265  related-1;request-0;offer-0;aid_related-0;medi...
#
# [26248 rows x 2 columns]

# %%
df_cat['Priority']=df_messages['Priority']

# %%
df_cat
# Out:
#           id                                         categories  Priority
# 0          2  related-1;request-0;offer-0;aid_related-0;medi...         1
# 1          7  related-1;request-0;offer-0;aid_related-1;medi...         2
# 2          8  related-1;request-0;offer-0;aid_related-0;medi...         2
# 3          9  related-1;request-1;offer-0;aid_related-1;medi...         2
# 4         12  related-1;request-0;offer-0;aid_related-0;medi...         1
# ...      ...                                                ...       ...
# 26243  30261  related-0;request-0;offer-0;aid_related-0;medi...         1
# 26244  30262  related-0;request-0;offer-0;aid_related-0;medi...         1
# 26245  30263  related-1;request-0;offer-0;aid_related-0;medi...         1
# 26246  30264  related-1;request-0;offer-0;aid_related-1;medi...         1
# 26247  30265  related-1;request-0;offer-0;aid_related-0;medi...         1
#
# [26248 rows x 3 columns]

# %%
df_cat.to_csv("New_Categories_edited.csv")
